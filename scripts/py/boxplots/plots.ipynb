# %%
import pandas as pd
from benchmark import run_experiments
import os
import os.path

here = os.path.dirname(os.path.dirname("__file__"))
PROJECT_DIR = os.path.abspath(os.path.join(here, "../../.."))

# %%
T = pd.read_csv(os.path.join(PROJECT_DIR, "exp/crossings/dna/results/time.csv"))
M = pd.read_csv(os.path.join(PROJECT_DIR, "exp/crossings/dna/results/mem.csv"))
O = pd.read_csv(os.path.join(PROJECT_DIR, "exp/crossings/dna/results/outputs.csv"))
T
# Out:
#                                                  query filesize    nchars  \
# 0    !x{[DEQGSTALMKRH][LIVMFYSTAC][GNQ][LIVMFYAG][D...      37M  38534725
# 1    !x{C.C.{2}[GP][FYW].{4,8}C.{0,100}P.{8,10}[LM]...      37M  38534725
# 2    !x{C.{2,4}C.{3}[LIVMFYWC].{8}H.{3,5}H.{0,100}C...      37M  38534725
# 3    !x{[FW][SGNH].[GD][^F][RKHPT][^P]C[LIVMFAP][GA...      37M  38534725
# 4    !x{C.{2,4}C.{3}[LIVMFYWC].{8}H.{3,5}H.{0,100}R...      37M  38534725
# ..                                                 ...      ...       ...
# 97                   !x{[ST].[RK].{0,100}[RK]{2}.[ST]}      37M  38534725
# 98                   !x{[RK]{2}.[ST].{0,100}[ST].[RK]}      37M  38534725
# 99   !x{G[^EDRKHPFYW].{2}[STAGCN][^P].{0,100}N[^P][...      37M  38534725
# 100              !x{N[^P][ST][^P].{0,100}[ST].{2}[DE]}      37M  38534725
# 101              !x{[ST].{2}[DE].{0,100}N[^P][ST][^P]}      37M  38534725
#
#      nlines  size(eVA)  size(d-eVA)  size(md-eVA)  size(segments)     SDFA  \
# ...

# %%
bp = T.boxplot(column=['SDFA', 'REm', 're2', 're2-f', 'PCRE', 'PCRE-f', 'boost', 'boost-f', 'onig'])

# %%
print(*range(0, 101, 17))
# Out:
# 0 17 34 51 68 85

# %%
df_list = [T.iloc[range(i,i+17),:] for i in range(0,101,17)]
df_list
# Out:
# [                                                query filesize    nchars  \
#  0   !x{[DEQGSTALMKRH][LIVMFYSTAC][GNQ][LIVMFYAG][D...      37M  38534725
#  1   !x{C.C.{2}[GP][FYW].{4,8}C.{0,100}P.{8,10}[LM]...      37M  38534725
#  2   !x{C.{2,4}C.{3}[LIVMFYWC].{8}H.{3,5}H.{0,100}C...      37M  38534725
#  3   !x{[FW][SGNH].[GD][^F][RKHPT][^P]C[LIVMFAP][GA...      37M  38534725
#  4   !x{C.{2,4}C.{3}[LIVMFYWC].{8}H.{3,5}H.{0,100}R...      37M  38534725
#  5   !x{[RK]{2}.[ST].{0,100}[DNSTAGC][GSTAPIMVQH].{...      37M  38534725
#  6   !x{C.C.{2}[^V].{2}G[^C].C.{0,100}L.{6}L.{6}L.{...      37M  38534725
#  7   !x{C.[DN].{4}[FY].C.C.{0,100}[FYWHPVAS].{3}C.{...      37M  38534725
#  8   !x{[RK].{3}[DE].{2}Y.{0,100}L[FYW][QEDH]F[LI][...      37M  38534725
#  9   !x{[RK].{2}[DE].{3}Y.{0,100}H.[LIVMFYW].{8,11}...      37M  38534725
#  10  !x{[DNSTAGC][GSTAPIMVQH].{2}G[DE]SG[GS][SAPHV]...      37M  38534725
#  11  !x{C.C.{2}[^V].{2}G[^C].C.{0,100}C[LIVMFYATG]....      37M  38534725
# ...

# %%
bp = df_list[0].boxplot(column=['SDFA', 'REm', 're2', 're2-f', 'PCRE', 'PCRE-f', 'boost', 'boost-f', 'onig'])

# %%
bp = df_list[1].boxplot(column=['SDFA', 'REm', 're2', 're2-f', 'PCRE', 'PCRE-f', 'boost', 'boost-f', 'onig'])

# %%
bp = df_list[2].boxplot(column=['SDFA', 'REm', 're2', 're2-f', 'PCRE', 'PCRE-f', 'boost', 'boost-f', 'onig'])

# %%
bp = df_list[3].boxplot(column=['SDFA', 'REm', 're2', 're2-f', 'PCRE', 'PCRE-f', 'boost', 'boost-f', 'onig'])

# %%
bp = df_list[4].boxplot(column=['SDFA', 'REm', 're2', 're2-f', 'PCRE', 'PCRE-f', 'boost', 'boost-f', 'onig'])

# %%
bp = df_list[5].boxplot(column=['SDFA', 'REm', 're2', 're2-f', 'PCRE', 'PCRE-f', 'boost', 'boost-f', 'onig'])
