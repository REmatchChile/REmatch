# %%
import pandas as pd
import os
import os.path
import csv
from math import log10, ceil, floor
import re
import random
from pprint import pprint

here = os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR = os.path.abspath(os.path.join(here, "../.."))

ENGLISH = os.path.join(PROJECT_DIR, 'datasets/english-works/english-authors.txt')
SPARQL = os.path.join(PROJECT_DIR, 'datasets/RKBExplorer/sparql.log.1')

# %%
def split_in_bins(df):
  df_zeros = df[df["noutputs"] > 0]
  df_zeros = df_zeros.sort_values(by=['noutputs'], ascending=False)
  max_val = df_zeros['noutputs'].iloc[0]
  min_val = df_zeros['noutputs'].iloc[-1]
  output_dfs = []
  for i in range(floor(log10(min_val)), ceil(log10(max_val))):
    ndf = df_zeros[(10**i <= df_zeros['noutputs']) & (df_zeros['noutputs'] < 10**(i+1))]
    ndf = ndf.assign(bin_range_min=10**i)
    ndf = ndf.assign(bin_range_max=10**(i+1))
    output_dfs.append(ndf)
  return output_dfs

def get_sample_queries(df):
  bins = split_in_bins(df)
  min_len = min(map(len, bins))
  sample_queries = []
  for dframe in bins[::-1]:
    dframe = dframe.sample(frac=1)
    dframe.reset_index(inplace=True, drop=True)
    sample_queries.append(dframe.head(min_len))

  return pd.concat(sample_queries)

def get_first_rows(df, nrows):
  df_zeros = df[df["noutputs"] > 0]
  df_zeros = df_zeros.sort_values(by=['noutputs'], ascending=False)
  df_zeros = df_zeros.reset_index(drop=True)
  return df_zeros.head(nrows)

def to_csv(df, filename):
  df.to_csv(os.path.join(here, filename), quoting=csv.QUOTE_NONNUMERIC)

# %%
df = pd.read_csv(os.path.join(here, 'multi-ops.csv'), index_col=[0])

df['query'] = df['query'].map(lambda x: re.search('!x{(.+)}', x).group(1))

df = get_sample_queries(df)
df
# Out:
#                                                 query  noutputs  \
# 0   [^\n]* WHERE [^\n]*\n[^\n]* PREFIX [^\n]* SELE...    100617
# 1   [^\n]* SELECT [^\n]* WHERE [^\n]*\n[^\n]* SELE...    101196
# 2           [^\n]* PREFIX [^\n]*\n[^\n]* WHERE [^\n]*    100633
# 3   [^\n]* SELECT [^\n]* WHERE [^\n]*\n[^\n]* WHER...    105706
# 4   [^\n]* PREFIX [^\n]* WHERE [^\n]*\n[^\n]* WHER...    100621
# ..                                                ...       ...
# 29  [^\n]* OPTIONAL [^\n]* FILTER [^\n]*\n[^\n]* S...        29
# 30  [^\n]* PREFIX [^\n]* ORDER BY [^\n]*\n[^\n]* O...        54
# 31  [^\n]* AS [^\n]* WHERE [^\n]*\n[^\n]* OPTIONAL...        73
# 32  [^\n]* SELECT [^\n]* OPTIONAL [^\n]* OPTIONAL ...        67
# 33  [^\n]* AS [^\n]* WHERE [^\n]*\n[^\n]* DISTINCT...        69
#
#     bin_range_min  bin_range_max
# 0          100000        1000000
# 1          100000        1000000
# 2          100000        1000000
# 3          100000        1000000
# 4          100000        1000000
# ..            ...            ...
# 29             10            100
# 30             10            100
# 31             10            100
# 32             10            100
# 33             10            100
#
# [170 rows x 4 columns]

# %%
for i, row in df.iterrows():
  exp_path = os.path.join(PROJECT_DIR, f'exp/crossings/sparql/2lines/sample/k{row["bin_range_max"]}/exp{i:03}')
  os.makedirs(exp_path, exist_ok=True)
  if(os.path.exists(os.path.join(exp_path, 'doc.txt'))):
    os.remove(os.path.join(exp_path, 'doc.txt'))
  os.symlink(SPARQL, os.path.join(exp_path, 'doc.txt'))
  with open(os.path.join(exp_path, 'rematch.rgx'), 'w') as fp:
    fp.write(f'!x{{\\n{row["query"]}\\n}}')
  with open(os.path.join(exp_path, 'perl.rgx'), 'w') as fp:
    fp.write(f'(\\n{row["query"]}\\n)')
  with open(os.path.join(exp_path, 'boost.rgx'), 'w') as fp:
    fp.write(f'(\\n{row["query"]}\\n)')

# %%
import itertools

for i, s in enumerate(itertools.combinations(df['query'], 3)):
  exp_path = os.path.join(PROJECT_DIR, f'exp/morphemes/40choose3/exp{i:04}')
  os.makedirs(exp_path, exist_ok=True)
  if(os.path.exists(os.path.join(exp_path, 'doc.txt'))):
    os.remove(os.path.join(exp_path, 'doc.txt'))
  os.symlink(ENGLISH, os.path.join(exp_path, 'doc.txt'))
  capture = f"{s[0]}|{s[1]}|{s[2]}"
  with open(os.path.join(exp_path, 'rematch.rgx'), 'w') as fp:
    fp.write(f'\W!x{{(({capture})\W+){{5}}({capture})}}\W')
  with open(os.path.join(exp_path, 'perl.rgx'), 'w') as fp:
    fp.write(f'\W((?:(?:{capture})\W+){{5}}(?:{capture}))\W')
  with open(os.path.join(exp_path, 'boost.rgx'), 'w') as fp:
    fp.write(f'\W((?:(?:{capture})\W+){{5}}(?:{capture}))\W')

# %%
df = pd.read_csv(os.path.join(here, 'morpheme.csv'), index_col=[0])
df = get_first_rows(df, 100)
df['query'] = df['query'].map(lambda x: re.fullmatch('\\\\W!x{(.+)}\\\\W', x).group(1))

# %%
cross = []
for i, r1 in df.iterrows():
  for j, r2 in df.iterrows():
    cross.append(f'{r1["query"]}\W{r2["query"]}')

cross
# Out:
# ['a\\w+\\Wa\\w+',
#  'a\\w+\\Wan\\w+',
#  'a\\w+\\W\\w+er',
#  'a\\w+\\Wco\\w+',
#  'a\\w+\\W\\w+ly',
#  'a\\w+\\Wbe\\w+',
#  'a\\w+\\Wre\\w+',
#  'a\\w+\\W\\w+or',
#  'a\\w+\\W\\w+ion',
#  'a\\w+\\Win\\w+',
#  'a\\w+\\Wde\\w+',
#  'a\\w+\\Wdi\\w+',
#  'a\\w+\\W\\w+ent',
#  'a\\w+\\W\\w+geo?\\w+',
#  'a\\w+\\W\\w+al',
#  'a\\w+\\Wcom\\w+',
#  'a\\w+\\Wcon\\w+',
#  'a\\w+\\Wun\\w+',
#  'a\\w+\\Wex\\w+',
#  'a\\w+\\Wen\\w+',
#  'a\\w+\\Wpro\\w+',
#  'a\\w+\\W\\w+ation',
#  'a\\w+\\W\\w+ive',
#  'a\\w+\\Wdis\\w+',
#  'a\\w+\\W\\w+ous',
#  'a\\w+\\W\\w+ate',
#  'a\\w+\\W\\w+ure',
#  'a\\w+\\Wpre\\w+',
#  'a\\w+\\W\\w+ment',
#  'a\\w+\\W\\w+ence',
#  'a\\w+\\W\\w+able',
#  'a\\w+\\W\\w+ant',
#  'a\\w+\\W\\w+ity',
#  'a\\w+\\W\\w+ness',
#  'a\\w+\\W\\w+ance',
#  'a\\w+\\W\\w+ful',
#  'a\\w+\\Wim\\w+',
#  'a\\w+\\W\\w+age',
#  'a\\w+\\W\\w+ish',
#  'a\\w+\\W\\w+ic',
#  'a\\w+\\W\\w+ary',
#  'a\\w+\\W\\w+mi[ts]\\w+',
#  'a\\w+\\W\\w+bio?\\w+',
#  'a\\w+\\W\\w+ise',
#  'a\\w+\\Wbi\\w+',
#  'a\\w+\\W\\w+less',
#  'a\\w+\\Winter\\w+',
#  'a\\w+\\Wmis\\w+',
#  'a\\w+\\W\\w+ible',
#  'a\\w+\\Wcol\\w+',
#  'a\\w+\\Wtri\\w+',
#  'a\\w+\\W\\w+spect?\\w+',
#  'a\\w+\\Wem\\w+',
#  'a\\w+\\W\\w+pan\\w+',
#  'a\\w+\\W\\w+ver[ts]\\w+',
#  'a\\w+\\Wsub\\w+',
#  'a\\w+\\W\\w+press\\w+',
#  'a\\w+\\W\\w+port\\w+',
#  'a\\w+\\W\\w+ian',
#  'a\\w+\\W\\w+auto?\\w+',
#  'a\\w+\\W\\w+ist',
#  'a\\w+\\W\\w+dict?\\w+',
#  'a\\w+\\W\\w+form\\w+',
#  'a\\w+\\Wil\\w+',
#  'a\\w+\\Wnon\\w+',
#  'a\\w+\\W\\w+ship',
#  'a\\w+\\W\\w+scri(pt|b)\\w+',
#  'a\\w+\\W\\w+stru(ct)?\\w+',
#  'a\\w+\\W\\w+eer',
#  'a\\w+\\W\\w+c[ae]pt\\w+',
#  'a\\w+\\W\\w+cial',
#  'a\\w+\\W\\w+cide\\w+',
#  'a\\w+\\W\\w+fact?\\w+',
#  'a\\w+\\W\\w+p(el|uls)\\w+',
#  'a\\w+\\Wir\\w+',
#  'a\\w+\\W\\w+ject\\w+',
#  'a\\w+\\W\\w+tude',
#  'a\\w+\\Wuni\\w+',
#  'a\\w+\\W\\w+hood',
#  'a\\w+\\W\\w+tract\\w+',
#  'a\\w+\\W\\w+ize',
#  'a\\w+\\W\\w+pa(th|ss)\\w+',
#  'a\\w+\\Wcontra\\w+',
#  'a\\w+\\Wbene\\w+',
#  'a\\w+\\Wtrans\\w+',
#  'a\\w+\\W\\w+fle[cx]\\w+',
#  'a\\w+\\W\\w+rupt\\w+',
#  'a\\w+\\W\\w+graph\\w+',
#  'a\\w+\\Wpost\\w+',
#  'a\\w+\\W\\w+tial',
#  'a\\w+\\Wmal\\w+',
#  'a\\w+\\W\\w+ism',
#  'a\\w+\\Wdia\\w+',
#  'a\\w+\\W\\w+homo?\\w+',
#  'a\\w+\\Wmulti\\w+',
#  'a\\w+\\W\\w+gr(ad|ess)\\w+',
#  'a\\w+\\Wanti\\w+',
#  'a\\w+\\Wmono\\w+',
#  'a\\w+\\W\\w+logy',
#  'a\\w+\\W\\w+spire\\w+',
#  'an\\w+\\Wa\\w+',
#  'an\\w+\\Wan\\w+',
#  'an\\w+\\W\\w+er',
#  'an\\w+\\Wco\\w+',
#  'an\\w+\\W\\w+ly',
#  'an\\w+\\Wbe\\w+',
#  'an\\w+\\Wre\\w+',
#  'an\\w+\\W\\w+or',
#  'an\\w+\\W\\w+ion',
#  'an\\w+\\Win\\w+',
#  'an\\w+\\Wde\\w+',
#  'an\\w+\\Wdi\\w+',
#  'an\\w+\\W\\w+ent',
#  'an\\w+\\W\\w+geo?\\w+',
#  'an\\w+\\W\\w+al',
#  'an\\w+\\Wcom\\w+',
#  'an\\w+\\Wcon\\w+',
#  'an\\w+\\Wun\\w+',
#  'an\\w+\\Wex\\w+',
#  'an\\w+\\Wen\\w+',
#  'an\\w+\\Wpro\\w+',
#  'an\\w+\\W\\w+ation',
#  'an\\w+\\W\\w+ive',
#  'an\\w+\\Wdis\\w+',
#  'an\\w+\\W\\w+ous',
#  'an\\w+\\W\\w+ate',
#  'an\\w+\\W\\w+ure',
#  'an\\w+\\Wpre\\w+',
#  'an\\w+\\W\\w+ment',
#  'an\\w+\\W\\w+ence',
#  'an\\w+\\W\\w+able',
#  'an\\w+\\W\\w+ant',
#  'an\\w+\\W\\w+ity',
#  'an\\w+\\W\\w+ness',
#  'an\\w+\\W\\w+ance',
#  'an\\w+\\W\\w+ful',
#  'an\\w+\\Wim\\w+',
#  'an\\w+\\W\\w+age',
#  'an\\w+\\W\\w+ish',
#  'an\\w+\\W\\w+ic',
#  'an\\w+\\W\\w+ary',
#  'an\\w+\\W\\w+mi[ts]\\w+',
#  'an\\w+\\W\\w+bio?\\w+',
#  'an\\w+\\W\\w+ise',
#  'an\\w+\\Wbi\\w+',
#  'an\\w+\\W\\w+less',
#  'an\\w+\\Winter\\w+',
#  'an\\w+\\Wmis\\w+',
#  'an\\w+\\W\\w+ible',
#  'an\\w+\\Wcol\\w+',
#  'an\\w+\\Wtri\\w+',
#  'an\\w+\\W\\w+spect?\\w+',
#  'an\\w+\\Wem\\w+',
#  'an\\w+\\W\\w+pan\\w+',
#  'an\\w+\\W\\w+ver[ts]\\w+',
#  'an\\w+\\Wsub\\w+',
#  'an\\w+\\W\\w+press\\w+',
#  'an\\w+\\W\\w+port\\w+',
#  'an\\w+\\W\\w+ian',
#  'an\\w+\\W\\w+auto?\\w+',
#  'an\\w+\\W\\w+ist',
#  'an\\w+\\W\\w+dict?\\w+',
#  'an\\w+\\W\\w+form\\w+',
#  'an\\w+\\Wil\\w+',
#  'an\\w+\\Wnon\\w+',
#  'an\\w+\\W\\w+ship',
#  'an\\w+\\W\\w+scri(pt|b)\\w+',
#  'an\\w+\\W\\w+stru(ct)?\\w+',
#  'an\\w+\\W\\w+eer',
#  'an\\w+\\W\\w+c[ae]pt\\w+',
#  'an\\w+\\W\\w+cial',
#  'an\\w+\\W\\w+cide\\w+',
#  'an\\w+\\W\\w+fact?\\w+',
#  'an\\w+\\W\\w+p(el|uls)\\w+',
#  'an\\w+\\Wir\\w+',
#  'an\\w+\\W\\w+ject\\w+',
#  'an\\w+\\W\\w+tude',
#  'an\\w+\\Wuni\\w+',
#  'an\\w+\\W\\w+hood',
#  'an\\w+\\W\\w+tract\\w+',
#  'an\\w+\\W\\w+ize',
#  'an\\w+\\W\\w+pa(th|ss)\\w+',
#  'an\\w+\\Wcontra\\w+',
#  'an\\w+\\Wbene\\w+',
#  'an\\w+\\Wtrans\\w+',
#  'an\\w+\\W\\w+fle[cx]\\w+',
#  'an\\w+\\W\\w+rupt\\w+',
#  'an\\w+\\W\\w+graph\\w+',
#  'an\\w+\\Wpost\\w+',
#  'an\\w+\\W\\w+tial',
#  'an\\w+\\Wmal\\w+',
#  'an\\w+\\W\\w+ism',
#  'an\\w+\\Wdia\\w+',
#  'an\\w+\\W\\w+homo?\\w+',
#  'an\\w+\\Wmulti\\w+',
#  'an\\w+\\W\\w+gr(ad|ess)\\w+',
#  'an\\w+\\Wanti\\w+',
#  'an\\w+\\Wmono\\w+',
#  'an\\w+\\W\\w+logy',
#  'an\\w+\\W\\w+spire\\w+',
#  '\\w+er\\Wa\\w+',
#  '\\w+er\\Wan\\w+',
#  '\\w+er\\W\\w+er',
#  '\\w+er\\Wco\\w+',
#  '\\w+er\\W\\w+ly',
#  '\\w+er\\Wbe\\w+',
#  '\\w+er\\Wre\\w+',
#  '\\w+er\\W\\w+or',
#  '\\w+er\\W\\w+ion',
#  '\\w+er\\Win\\w+',
#  '\\w+er\\Wde\\w+',
#  '\\w+er\\Wdi\\w+',
#  '\\w+er\\W\\w+ent',
#  '\\w+er\\W\\w+geo?\\w+',
#  '\\w+er\\W\\w+al',
#  '\\w+er\\Wcom\\w+',
#  '\\w+er\\Wcon\\w+',
#  '\\w+er\\Wun\\w+',
#  '\\w+er\\Wex\\w+',
#  '\\w+er\\Wen\\w+',
#  '\\w+er\\Wpro\\w+',
#  '\\w+er\\W\\w+ation',
#  '\\w+er\\W\\w+ive',
#  '\\w+er\\Wdis\\w+',
#  '\\w+er\\W\\w+ous',
#  '\\w+er\\W\\w+ate',
#  '\\w+er\\W\\w+ure',
#  '\\w+er\\Wpre\\w+',
#  '\\w+er\\W\\w+ment',
#  '\\w+er\\W\\w+ence',
#  '\\w+er\\W\\w+able',
#  '\\w+er\\W\\w+ant',
#  '\\w+er\\W\\w+ity',
#  '\\w+er\\W\\w+ness',
#  '\\w+er\\W\\w+ance',
#  '\\w+er\\W\\w+ful',
#  '\\w+er\\Wim\\w+',
#  '\\w+er\\W\\w+age',
#  '\\w+er\\W\\w+ish',
#  '\\w+er\\W\\w+ic',
#  '\\w+er\\W\\w+ary',
#  '\\w+er\\W\\w+mi[ts]\\w+',
#  '\\w+er\\W\\w+bio?\\w+',
#  '\\w+er\\W\\w+ise',
#  '\\w+er\\Wbi\\w+',
#  '\\w+er\\W\\w+less',
#  '\\w+er\\Winter\\w+',
#  '\\w+er\\Wmis\\w+',
#  '\\w+er\\W\\w+ible',
#  '\\w+er\\Wcol\\w+',
#  '\\w+er\\Wtri\\w+',
#  '\\w+er\\W\\w+spect?\\w+',
#  '\\w+er\\Wem\\w+',
#  '\\w+er\\W\\w+pan\\w+',
#  '\\w+er\\W\\w+ver[ts]\\w+',
#  '\\w+er\\Wsub\\w+',
#  '\\w+er\\W\\w+press\\w+',
#  '\\w+er\\W\\w+port\\w+',
#  '\\w+er\\W\\w+ian',
#  '\\w+er\\W\\w+auto?\\w+',
#  '\\w+er\\W\\w+ist',
#  '\\w+er\\W\\w+dict?\\w+',
#  '\\w+er\\W\\w+form\\w+',
#  '\\w+er\\Wil\\w+',
#  '\\w+er\\Wnon\\w+',
#  '\\w+er\\W\\w+ship',
#  '\\w+er\\W\\w+scri(pt|b)\\w+',
#  '\\w+er\\W\\w+stru(ct)?\\w+',
#  '\\w+er\\W\\w+eer',
#  '\\w+er\\W\\w+c[ae]pt\\w+',
#  '\\w+er\\W\\w+cial',
#  '\\w+er\\W\\w+cide\\w+',
#  '\\w+er\\W\\w+fact?\\w+',
#  '\\w+er\\W\\w+p(el|uls)\\w+',
#  '\\w+er\\Wir\\w+',
#  '\\w+er\\W\\w+ject\\w+',
#  '\\w+er\\W\\w+tude',
#  '\\w+er\\Wuni\\w+',
#  '\\w+er\\W\\w+hood',
#  '\\w+er\\W\\w+tract\\w+',
#  '\\w+er\\W\\w+ize',
#  '\\w+er\\W\\w+pa(th|ss)\\w+',
#  '\\w+er\\Wcontra\\w+',
#  '\\w+er\\Wbene\\w+',
#  '\\w+er\\Wtrans\\w+',
#  '\\w+er\\W\\w+fle[cx]\\w+',
#  '\\w+er\\W\\w+rupt\\w+',
#  '\\w+er\\W\\w+graph\\w+',
#  '\\w+er\\Wpost\\w+',
#  '\\w+er\\W\\w+tial',
#  '\\w+er\\Wmal\\w+',
#  '\\w+er\\W\\w+ism',
#  '\\w+er\\Wdia\\w+',
#  '\\w+er\\W\\w+homo?\\w+',
#  '\\w+er\\Wmulti\\w+',
#  '\\w+er\\W\\w+gr(ad|ess)\\w+',
#  '\\w+er\\Wanti\\w+',
#  '\\w+er\\Wmono\\w+',
#  '\\w+er\\W\\w+logy',
#  '\\w+er\\W\\w+spire\\w+',
#  'co\\w+\\Wa\\w+',
#  'co\\w+\\Wan\\w+',
#  'co\\w+\\W\\w+er',
#  'co\\w+\\Wco\\w+',
#  'co\\w+\\W\\w+ly',
#  'co\\w+\\Wbe\\w+',
#  'co\\w+\\Wre\\w+',
#  'co\\w+\\W\\w+or',
#  'co\\w+\\W\\w+ion',
#  'co\\w+\\Win\\w+',
#  'co\\w+\\Wde\\w+',
#  'co\\w+\\Wdi\\w+',
#  'co\\w+\\W\\w+ent',
#  'co\\w+\\W\\w+geo?\\w+',
#  'co\\w+\\W\\w+al',
#  'co\\w+\\Wcom\\w+',
#  'co\\w+\\Wcon\\w+',
#  'co\\w+\\Wun\\w+',
#  'co\\w+\\Wex\\w+',
#  'co\\w+\\Wen\\w+',
#  'co\\w+\\Wpro\\w+',
#  'co\\w+\\W\\w+ation',
#  'co\\w+\\W\\w+ive',
#  'co\\w+\\Wdis\\w+',
#  'co\\w+\\W\\w+ous',
#  'co\\w+\\W\\w+ate',
#  'co\\w+\\W\\w+ure',
#  'co\\w+\\Wpre\\w+',
#  'co\\w+\\W\\w+ment',
#  'co\\w+\\W\\w+ence',
#  'co\\w+\\W\\w+able',
#  'co\\w+\\W\\w+ant',
#  'co\\w+\\W\\w+ity',
#  'co\\w+\\W\\w+ness',
#  'co\\w+\\W\\w+ance',
#  'co\\w+\\W\\w+ful',
#  'co\\w+\\Wim\\w+',
#  'co\\w+\\W\\w+age',
#  'co\\w+\\W\\w+ish',
#  'co\\w+\\W\\w+ic',
#  'co\\w+\\W\\w+ary',
#  'co\\w+\\W\\w+mi[ts]\\w+',
#  'co\\w+\\W\\w+bio?\\w+',
#  'co\\w+\\W\\w+ise',
#  'co\\w+\\Wbi\\w+',
#  'co\\w+\\W\\w+less',
#  'co\\w+\\Winter\\w+',
#  'co\\w+\\Wmis\\w+',
#  'co\\w+\\W\\w+ible',
#  'co\\w+\\Wcol\\w+',
#  'co\\w+\\Wtri\\w+',
#  'co\\w+\\W\\w+spect?\\w+',
#  'co\\w+\\Wem\\w+',
#  'co\\w+\\W\\w+pan\\w+',
#  'co\\w+\\W\\w+ver[ts]\\w+',
#  'co\\w+\\Wsub\\w+',
#  'co\\w+\\W\\w+press\\w+',
#  'co\\w+\\W\\w+port\\w+',
#  'co\\w+\\W\\w+ian',
#  'co\\w+\\W\\w+auto?\\w+',
#  'co\\w+\\W\\w+ist',
#  'co\\w+\\W\\w+dict?\\w+',
#  'co\\w+\\W\\w+form\\w+',
#  'co\\w+\\Wil\\w+',
#  'co\\w+\\Wnon\\w+',
#  'co\\w+\\W\\w+ship',
#  'co\\w+\\W\\w+scri(pt|b)\\w+',
#  'co\\w+\\W\\w+stru(ct)?\\w+',
#  'co\\w+\\W\\w+eer',
#  'co\\w+\\W\\w+c[ae]pt\\w+',
#  'co\\w+\\W\\w+cial',
#  'co\\w+\\W\\w+cide\\w+',
#  'co\\w+\\W\\w+fact?\\w+',
#  'co\\w+\\W\\w+p(el|uls)\\w+',
#  'co\\w+\\Wir\\w+',
#  'co\\w+\\W\\w+ject\\w+',
#  'co\\w+\\W\\w+tude',
#  'co\\w+\\Wuni\\w+',
#  'co\\w+\\W\\w+hood',
#  'co\\w+\\W\\w+tract\\w+',
#  'co\\w+\\W\\w+ize',
#  'co\\w+\\W\\w+pa(th|ss)\\w+',
#  'co\\w+\\Wcontra\\w+',
#  'co\\w+\\Wbene\\w+',
#  'co\\w+\\Wtrans\\w+',
#  'co\\w+\\W\\w+fle[cx]\\w+',
#  'co\\w+\\W\\w+rupt\\w+',
#  'co\\w+\\W\\w+graph\\w+',
#  'co\\w+\\Wpost\\w+',
#  'co\\w+\\W\\w+tial',
#  'co\\w+\\Wmal\\w+',
#  'co\\w+\\W\\w+ism',
#  'co\\w+\\Wdia\\w+',
#  'co\\w+\\W\\w+homo?\\w+',
#  'co\\w+\\Wmulti\\w+',
#  'co\\w+\\W\\w+gr(ad|ess)\\w+',
#  'co\\w+\\Wanti\\w+',
#  'co\\w+\\Wmono\\w+',
#  'co\\w+\\W\\w+logy',
#  'co\\w+\\W\\w+spire\\w+',
#  '\\w+ly\\Wa\\w+',
#  '\\w+ly\\Wan\\w+',
#  '\\w+ly\\W\\w+er',
#  '\\w+ly\\Wco\\w+',
#  '\\w+ly\\W\\w+ly',
#  '\\w+ly\\Wbe\\w+',
#  '\\w+ly\\Wre\\w+',
#  '\\w+ly\\W\\w+or',
#  '\\w+ly\\W\\w+ion',
#  '\\w+ly\\Win\\w+',
#  '\\w+ly\\Wde\\w+',
#  '\\w+ly\\Wdi\\w+',
#  '\\w+ly\\W\\w+ent',
#  '\\w+ly\\W\\w+geo?\\w+',
#  '\\w+ly\\W\\w+al',
#  '\\w+ly\\Wcom\\w+',
#  '\\w+ly\\Wcon\\w+',
#  '\\w+ly\\Wun\\w+',
#  '\\w+ly\\Wex\\w+',
#  '\\w+ly\\Wen\\w+',
#  '\\w+ly\\Wpro\\w+',
#  '\\w+ly\\W\\w+ation',
#  '\\w+ly\\W\\w+ive',
#  '\\w+ly\\Wdis\\w+',
#  '\\w+ly\\W\\w+ous',
#  '\\w+ly\\W\\w+ate',
#  '\\w+ly\\W\\w+ure',
#  '\\w+ly\\Wpre\\w+',
#  '\\w+ly\\W\\w+ment',
#  '\\w+ly\\W\\w+ence',
#  '\\w+ly\\W\\w+able',
#  '\\w+ly\\W\\w+ant',
#  '\\w+ly\\W\\w+ity',
#  '\\w+ly\\W\\w+ness',
#  '\\w+ly\\W\\w+ance',
#  '\\w+ly\\W\\w+ful',
#  '\\w+ly\\Wim\\w+',
#  '\\w+ly\\W\\w+age',
#  '\\w+ly\\W\\w+ish',
#  '\\w+ly\\W\\w+ic',
#  '\\w+ly\\W\\w+ary',
#  '\\w+ly\\W\\w+mi[ts]\\w+',
#  '\\w+ly\\W\\w+bio?\\w+',
#  '\\w+ly\\W\\w+ise',
#  '\\w+ly\\Wbi\\w+',
#  '\\w+ly\\W\\w+less',
#  '\\w+ly\\Winter\\w+',
#  '\\w+ly\\Wmis\\w+',
#  '\\w+ly\\W\\w+ible',
#  '\\w+ly\\Wcol\\w+',
#  '\\w+ly\\Wtri\\w+',
#  '\\w+ly\\W\\w+spect?\\w+',
#  '\\w+ly\\Wem\\w+',
#  '\\w+ly\\W\\w+pan\\w+',
#  '\\w+ly\\W\\w+ver[ts]\\w+',
#  '\\w+ly\\Wsub\\w+',
#  '\\w+ly\\W\\w+press\\w+',
#  '\\w+ly\\W\\w+port\\w+',
#  '\\w+ly\\W\\w+ian',
#  '\\w+ly\\W\\w+auto?\\w+',
#  '\\w+ly\\W\\w+ist',
#  '\\w+ly\\W\\w+dict?\\w+',
#  '\\w+ly\\W\\w+form\\w+',
#  '\\w+ly\\Wil\\w+',
#  '\\w+ly\\Wnon\\w+',
#  '\\w+ly\\W\\w+ship',
#  '\\w+ly\\W\\w+scri(pt|b)\\w+',
#  '\\w+ly\\W\\w+stru(ct)?\\w+',
#  '\\w+ly\\W\\w+eer',
#  '\\w+ly\\W\\w+c[ae]pt\\w+',
#  '\\w+ly\\W\\w+cial',
#  '\\w+ly\\W\\w+cide\\w+',
#  '\\w+ly\\W\\w+fact?\\w+',
#  '\\w+ly\\W\\w+p(el|uls)\\w+',
#  '\\w+ly\\Wir\\w+',
#  '\\w+ly\\W\\w+ject\\w+',
#  '\\w+ly\\W\\w+tude',
#  '\\w+ly\\Wuni\\w+',
#  '\\w+ly\\W\\w+hood',
#  '\\w+ly\\W\\w+tract\\w+',
#  '\\w+ly\\W\\w+ize',
#  '\\w+ly\\W\\w+pa(th|ss)\\w+',
#  '\\w+ly\\Wcontra\\w+',
#  '\\w+ly\\Wbene\\w+',
#  '\\w+ly\\Wtrans\\w+',
#  '\\w+ly\\W\\w+fle[cx]\\w+',
#  '\\w+ly\\W\\w+rupt\\w+',
#  '\\w+ly\\W\\w+graph\\w+',
#  '\\w+ly\\Wpost\\w+',
#  '\\w+ly\\W\\w+tial',
#  '\\w+ly\\Wmal\\w+',
#  '\\w+ly\\W\\w+ism',
#  '\\w+ly\\Wdia\\w+',
#  '\\w+ly\\W\\w+homo?\\w+',
#  '\\w+ly\\Wmulti\\w+',
#  '\\w+ly\\W\\w+gr(ad|ess)\\w+',
#  '\\w+ly\\Wanti\\w+',
#  '\\w+ly\\Wmono\\w+',
#  '\\w+ly\\W\\w+logy',
#  '\\w+ly\\W\\w+spire\\w+',
#  'be\\w+\\Wa\\w+',
#  'be\\w+\\Wan\\w+',
#  'be\\w+\\W\\w+er',
#  'be\\w+\\Wco\\w+',
#  'be\\w+\\W\\w+ly',
#  'be\\w+\\Wbe\\w+',
#  'be\\w+\\Wre\\w+',
#  'be\\w+\\W\\w+or',
#  'be\\w+\\W\\w+ion',
#  'be\\w+\\Win\\w+',
#  'be\\w+\\Wde\\w+',
#  'be\\w+\\Wdi\\w+',
#  'be\\w+\\W\\w+ent',
#  'be\\w+\\W\\w+geo?\\w+',
#  'be\\w+\\W\\w+al',
#  'be\\w+\\Wcom\\w+',
#  'be\\w+\\Wcon\\w+',
#  'be\\w+\\Wun\\w+',
#  'be\\w+\\Wex\\w+',
#  'be\\w+\\Wen\\w+',
#  'be\\w+\\Wpro\\w+',
#  'be\\w+\\W\\w+ation',
#  'be\\w+\\W\\w+ive',
#  'be\\w+\\Wdis\\w+',
#  'be\\w+\\W\\w+ous',
#  'be\\w+\\W\\w+ate',
#  'be\\w+\\W\\w+ure',
#  'be\\w+\\Wpre\\w+',
#  'be\\w+\\W\\w+ment',
#  'be\\w+\\W\\w+ence',
#  'be\\w+\\W\\w+able',
#  'be\\w+\\W\\w+ant',
#  'be\\w+\\W\\w+ity',
#  'be\\w+\\W\\w+ness',
#  'be\\w+\\W\\w+ance',
#  'be\\w+\\W\\w+ful',
#  'be\\w+\\Wim\\w+',
#  'be\\w+\\W\\w+age',
#  'be\\w+\\W\\w+ish',
#  'be\\w+\\W\\w+ic',
#  'be\\w+\\W\\w+ary',
#  'be\\w+\\W\\w+mi[ts]\\w+',
#  'be\\w+\\W\\w+bio?\\w+',
#  'be\\w+\\W\\w+ise',
#  'be\\w+\\Wbi\\w+',
#  'be\\w+\\W\\w+less',
#  'be\\w+\\Winter\\w+',
#  'be\\w+\\Wmis\\w+',
#  'be\\w+\\W\\w+ible',
#  'be\\w+\\Wcol\\w+',
#  'be\\w+\\Wtri\\w+',
#  'be\\w+\\W\\w+spect?\\w+',
#  'be\\w+\\Wem\\w+',
#  'be\\w+\\W\\w+pan\\w+',
#  'be\\w+\\W\\w+ver[ts]\\w+',
#  'be\\w+\\Wsub\\w+',
#  'be\\w+\\W\\w+press\\w+',
#  'be\\w+\\W\\w+port\\w+',
#  'be\\w+\\W\\w+ian',
#  'be\\w+\\W\\w+auto?\\w+',
#  'be\\w+\\W\\w+ist',
#  'be\\w+\\W\\w+dict?\\w+',
#  'be\\w+\\W\\w+form\\w+',
#  'be\\w+\\Wil\\w+',
#  'be\\w+\\Wnon\\w+',
#  'be\\w+\\W\\w+ship',
#  'be\\w+\\W\\w+scri(pt|b)\\w+',
#  'be\\w+\\W\\w+stru(ct)?\\w+',
#  'be\\w+\\W\\w+eer',
#  'be\\w+\\W\\w+c[ae]pt\\w+',
#  'be\\w+\\W\\w+cial',
#  'be\\w+\\W\\w+cide\\w+',
#  'be\\w+\\W\\w+fact?\\w+',
#  'be\\w+\\W\\w+p(el|uls)\\w+',
#  'be\\w+\\Wir\\w+',
#  'be\\w+\\W\\w+ject\\w+',
#  'be\\w+\\W\\w+tude',
#  'be\\w+\\Wuni\\w+',
#  'be\\w+\\W\\w+hood',
#  'be\\w+\\W\\w+tract\\w+',
#  'be\\w+\\W\\w+ize',
#  'be\\w+\\W\\w+pa(th|ss)\\w+',
#  'be\\w+\\Wcontra\\w+',
#  'be\\w+\\Wbene\\w+',
#  'be\\w+\\Wtrans\\w+',
#  'be\\w+\\W\\w+fle[cx]\\w+',
#  'be\\w+\\W\\w+rupt\\w+',
#  'be\\w+\\W\\w+graph\\w+',
#  'be\\w+\\Wpost\\w+',
#  'be\\w+\\W\\w+tial',
#  'be\\w+\\Wmal\\w+',
#  'be\\w+\\W\\w+ism',
#  'be\\w+\\Wdia\\w+',
#  'be\\w+\\W\\w+homo?\\w+',
#  'be\\w+\\Wmulti\\w+',
#  'be\\w+\\W\\w+gr(ad|ess)\\w+',
#  'be\\w+\\Wanti\\w+',
#  'be\\w+\\Wmono\\w+',
#  'be\\w+\\W\\w+logy',
#  'be\\w+\\W\\w+spire\\w+',
#  're\\w+\\Wa\\w+',
#  're\\w+\\Wan\\w+',
#  're\\w+\\W\\w+er',
#  're\\w+\\Wco\\w+',
#  're\\w+\\W\\w+ly',
#  're\\w+\\Wbe\\w+',
#  're\\w+\\Wre\\w+',
#  're\\w+\\W\\w+or',
#  're\\w+\\W\\w+ion',
#  're\\w+\\Win\\w+',
#  're\\w+\\Wde\\w+',
#  're\\w+\\Wdi\\w+',
#  're\\w+\\W\\w+ent',
#  're\\w+\\W\\w+geo?\\w+',
#  're\\w+\\W\\w+al',
#  're\\w+\\Wcom\\w+',
#  're\\w+\\Wcon\\w+',
#  're\\w+\\Wun\\w+',
#  're\\w+\\Wex\\w+',
#  're\\w+\\Wen\\w+',
#  're\\w+\\Wpro\\w+',
#  're\\w+\\W\\w+ation',
#  're\\w+\\W\\w+ive',
#  're\\w+\\Wdis\\w+',
#  're\\w+\\W\\w+ous',
#  're\\w+\\W\\w+ate',
#  're\\w+\\W\\w+ure',
#  're\\w+\\Wpre\\w+',
#  're\\w+\\W\\w+ment',
#  're\\w+\\W\\w+ence',
#  're\\w+\\W\\w+able',
#  're\\w+\\W\\w+ant',
#  're\\w+\\W\\w+ity',
#  're\\w+\\W\\w+ness',
#  're\\w+\\W\\w+ance',
#  're\\w+\\W\\w+ful',
#  're\\w+\\Wim\\w+',
#  're\\w+\\W\\w+age',
#  're\\w+\\W\\w+ish',
#  're\\w+\\W\\w+ic',
#  're\\w+\\W\\w+ary',
#  're\\w+\\W\\w+mi[ts]\\w+',
#  're\\w+\\W\\w+bio?\\w+',
#  're\\w+\\W\\w+ise',
#  're\\w+\\Wbi\\w+',
#  're\\w+\\W\\w+less',
#  're\\w+\\Winter\\w+',
#  're\\w+\\Wmis\\w+',
#  're\\w+\\W\\w+ible',
#  're\\w+\\Wcol\\w+',
#  're\\w+\\Wtri\\w+',
#  're\\w+\\W\\w+spect?\\w+',
#  're\\w+\\Wem\\w+',
#  're\\w+\\W\\w+pan\\w+',
#  're\\w+\\W\\w+ver[ts]\\w+',
#  're\\w+\\Wsub\\w+',
#  're\\w+\\W\\w+press\\w+',
#  're\\w+\\W\\w+port\\w+',
#  're\\w+\\W\\w+ian',
#  're\\w+\\W\\w+auto?\\w+',
#  're\\w+\\W\\w+ist',
#  're\\w+\\W\\w+dict?\\w+',
#  're\\w+\\W\\w+form\\w+',
#  're\\w+\\Wil\\w+',
#  're\\w+\\Wnon\\w+',
#  're\\w+\\W\\w+ship',
#  're\\w+\\W\\w+scri(pt|b)\\w+',
#  're\\w+\\W\\w+stru(ct)?\\w+',
#  're\\w+\\W\\w+eer',
#  're\\w+\\W\\w+c[ae]pt\\w+',
#  're\\w+\\W\\w+cial',
#  're\\w+\\W\\w+cide\\w+',
#  're\\w+\\W\\w+fact?\\w+',
#  're\\w+\\W\\w+p(el|uls)\\w+',
#  're\\w+\\Wir\\w+',
#  're\\w+\\W\\w+ject\\w+',
#  're\\w+\\W\\w+tude',
#  're\\w+\\Wuni\\w+',
#  're\\w+\\W\\w+hood',
#  're\\w+\\W\\w+tract\\w+',
#  're\\w+\\W\\w+ize',
#  're\\w+\\W\\w+pa(th|ss)\\w+',
#  're\\w+\\Wcontra\\w+',
#  're\\w+\\Wbene\\w+',
#  're\\w+\\Wtrans\\w+',
#  're\\w+\\W\\w+fle[cx]\\w+',
#  're\\w+\\W\\w+rupt\\w+',
#  're\\w+\\W\\w+graph\\w+',
#  're\\w+\\Wpost\\w+',
#  're\\w+\\W\\w+tial',
#  're\\w+\\Wmal\\w+',
#  're\\w+\\W\\w+ism',
#  're\\w+\\Wdia\\w+',
#  're\\w+\\W\\w+homo?\\w+',
#  're\\w+\\Wmulti\\w+',
#  're\\w+\\W\\w+gr(ad|ess)\\w+',
#  're\\w+\\Wanti\\w+',
#  're\\w+\\Wmono\\w+',
#  're\\w+\\W\\w+logy',
#  're\\w+\\W\\w+spire\\w+',
#  '\\w+or\\Wa\\w+',
#  '\\w+or\\Wan\\w+',
#  '\\w+or\\W\\w+er',
#  '\\w+or\\Wco\\w+',
#  '\\w+or\\W\\w+ly',
#  '\\w+or\\Wbe\\w+',
#  '\\w+or\\Wre\\w+',
#  '\\w+or\\W\\w+or',
#  '\\w+or\\W\\w+ion',
#  '\\w+or\\Win\\w+',
#  '\\w+or\\Wde\\w+',
#  '\\w+or\\Wdi\\w+',
#  '\\w+or\\W\\w+ent',
#  '\\w+or\\W\\w+geo?\\w+',
#  '\\w+or\\W\\w+al',
#  '\\w+or\\Wcom\\w+',
#  '\\w+or\\Wcon\\w+',
#  '\\w+or\\Wun\\w+',
#  '\\w+or\\Wex\\w+',
#  '\\w+or\\Wen\\w+',
#  '\\w+or\\Wpro\\w+',
#  '\\w+or\\W\\w+ation',
#  '\\w+or\\W\\w+ive',
#  '\\w+or\\Wdis\\w+',
#  '\\w+or\\W\\w+ous',
#  '\\w+or\\W\\w+ate',
#  '\\w+or\\W\\w+ure',
#  '\\w+or\\Wpre\\w+',
#  '\\w+or\\W\\w+ment',
#  '\\w+or\\W\\w+ence',
#  '\\w+or\\W\\w+able',
#  '\\w+or\\W\\w+ant',
#  '\\w+or\\W\\w+ity',
#  '\\w+or\\W\\w+ness',
#  '\\w+or\\W\\w+ance',
#  '\\w+or\\W\\w+ful',
#  '\\w+or\\Wim\\w+',
#  '\\w+or\\W\\w+age',
#  '\\w+or\\W\\w+ish',
#  '\\w+or\\W\\w+ic',
#  '\\w+or\\W\\w+ary',
#  '\\w+or\\W\\w+mi[ts]\\w+',
#  '\\w+or\\W\\w+bio?\\w+',
#  '\\w+or\\W\\w+ise',
#  '\\w+or\\Wbi\\w+',
#  '\\w+or\\W\\w+less',
#  '\\w+or\\Winter\\w+',
#  '\\w+or\\Wmis\\w+',
#  '\\w+or\\W\\w+ible',
#  '\\w+or\\Wcol\\w+',
#  '\\w+or\\Wtri\\w+',
#  '\\w+or\\W\\w+spect?\\w+',
#  '\\w+or\\Wem\\w+',
#  '\\w+or\\W\\w+pan\\w+',
#  '\\w+or\\W\\w+ver[ts]\\w+',
#  '\\w+or\\Wsub\\w+',
#  '\\w+or\\W\\w+press\\w+',
#  '\\w+or\\W\\w+port\\w+',
#  '\\w+or\\W\\w+ian',
#  '\\w+or\\W\\w+auto?\\w+',
#  '\\w+or\\W\\w+ist',
#  '\\w+or\\W\\w+dict?\\w+',
#  '\\w+or\\W\\w+form\\w+',
#  '\\w+or\\Wil\\w+',
#  '\\w+or\\Wnon\\w+',
#  '\\w+or\\W\\w+ship',
#  '\\w+or\\W\\w+scri(pt|b)\\w+',
#  '\\w+or\\W\\w+stru(ct)?\\w+',
#  '\\w+or\\W\\w+eer',
#  '\\w+or\\W\\w+c[ae]pt\\w+',
#  '\\w+or\\W\\w+cial',
#  '\\w+or\\W\\w+cide\\w+',
#  '\\w+or\\W\\w+fact?\\w+',
#  '\\w+or\\W\\w+p(el|uls)\\w+',
#  '\\w+or\\Wir\\w+',
#  '\\w+or\\W\\w+ject\\w+',
#  '\\w+or\\W\\w+tude',
#  '\\w+or\\Wuni\\w+',
#  '\\w+or\\W\\w+hood',
#  '\\w+or\\W\\w+tract\\w+',
#  '\\w+or\\W\\w+ize',
#  '\\w+or\\W\\w+pa(th|ss)\\w+',
#  '\\w+or\\Wcontra\\w+',
#  '\\w+or\\Wbene\\w+',
#  '\\w+or\\Wtrans\\w+',
#  '\\w+or\\W\\w+fle[cx]\\w+',
#  '\\w+or\\W\\w+rupt\\w+',
#  '\\w+or\\W\\w+graph\\w+',
#  '\\w+or\\Wpost\\w+',
#  '\\w+or\\W\\w+tial',
#  '\\w+or\\Wmal\\w+',
#  '\\w+or\\W\\w+ism',
#  '\\w+or\\Wdia\\w+',
#  '\\w+or\\W\\w+homo?\\w+',
#  '\\w+or\\Wmulti\\w+',
#  '\\w+or\\W\\w+gr(ad|ess)\\w+',
#  '\\w+or\\Wanti\\w+',
#  '\\w+or\\Wmono\\w+',
#  '\\w+or\\W\\w+logy',
#  '\\w+or\\W\\w+spire\\w+',
#  '\\w+ion\\Wa\\w+',
#  '\\w+ion\\Wan\\w+',
#  '\\w+ion\\W\\w+er',
#  '\\w+ion\\Wco\\w+',
#  '\\w+ion\\W\\w+ly',
#  '\\w+ion\\Wbe\\w+',
#  '\\w+ion\\Wre\\w+',
#  '\\w+ion\\W\\w+or',
#  '\\w+ion\\W\\w+ion',
#  '\\w+ion\\Win\\w+',
#  '\\w+ion\\Wde\\w+',
#  '\\w+ion\\Wdi\\w+',
#  '\\w+ion\\W\\w+ent',
#  '\\w+ion\\W\\w+geo?\\w+',
#  '\\w+ion\\W\\w+al',
#  '\\w+ion\\Wcom\\w+',
#  '\\w+ion\\Wcon\\w+',
#  '\\w+ion\\Wun\\w+',
#  '\\w+ion\\Wex\\w+',
#  '\\w+ion\\Wen\\w+',
#  '\\w+ion\\Wpro\\w+',
#  '\\w+ion\\W\\w+ation',
#  '\\w+ion\\W\\w+ive',
#  '\\w+ion\\Wdis\\w+',
#  '\\w+ion\\W\\w+ous',
#  '\\w+ion\\W\\w+ate',
#  '\\w+ion\\W\\w+ure',
#  '\\w+ion\\Wpre\\w+',
#  '\\w+ion\\W\\w+ment',
#  '\\w+ion\\W\\w+ence',
#  '\\w+ion\\W\\w+able',
#  '\\w+ion\\W\\w+ant',
#  '\\w+ion\\W\\w+ity',
#  '\\w+ion\\W\\w+ness',
#  '\\w+ion\\W\\w+ance',
#  '\\w+ion\\W\\w+ful',
#  '\\w+ion\\Wim\\w+',
#  '\\w+ion\\W\\w+age',
#  '\\w+ion\\W\\w+ish',
#  '\\w+ion\\W\\w+ic',
#  '\\w+ion\\W\\w+ary',
#  '\\w+ion\\W\\w+mi[ts]\\w+',
#  '\\w+ion\\W\\w+bio?\\w+',
#  '\\w+ion\\W\\w+ise',
#  '\\w+ion\\Wbi\\w+',
#  '\\w+ion\\W\\w+less',
#  '\\w+ion\\Winter\\w+',
#  '\\w+ion\\Wmis\\w+',
#  '\\w+ion\\W\\w+ible',
#  '\\w+ion\\Wcol\\w+',
#  '\\w+ion\\Wtri\\w+',
#  '\\w+ion\\W\\w+spect?\\w+',
#  '\\w+ion\\Wem\\w+',
#  '\\w+ion\\W\\w+pan\\w+',
#  '\\w+ion\\W\\w+ver[ts]\\w+',
#  '\\w+ion\\Wsub\\w+',
#  '\\w+ion\\W\\w+press\\w+',
#  '\\w+ion\\W\\w+port\\w+',
#  '\\w+ion\\W\\w+ian',
#  '\\w+ion\\W\\w+auto?\\w+',
#  '\\w+ion\\W\\w+ist',
#  '\\w+ion\\W\\w+dict?\\w+',
#  '\\w+ion\\W\\w+form\\w+',
#  '\\w+ion\\Wil\\w+',
#  '\\w+ion\\Wnon\\w+',
#  '\\w+ion\\W\\w+ship',
#  '\\w+ion\\W\\w+scri(pt|b)\\w+',
#  '\\w+ion\\W\\w+stru(ct)?\\w+',
#  '\\w+ion\\W\\w+eer',
#  '\\w+ion\\W\\w+c[ae]pt\\w+',
#  '\\w+ion\\W\\w+cial',
#  '\\w+ion\\W\\w+cide\\w+',
#  '\\w+ion\\W\\w+fact?\\w+',
#  '\\w+ion\\W\\w+p(el|uls)\\w+',
#  '\\w+ion\\Wir\\w+',
#  '\\w+ion\\W\\w+ject\\w+',
#  '\\w+ion\\W\\w+tude',
#  '\\w+ion\\Wuni\\w+',
#  '\\w+ion\\W\\w+hood',
#  '\\w+ion\\W\\w+tract\\w+',
#  '\\w+ion\\W\\w+ize',
#  '\\w+ion\\W\\w+pa(th|ss)\\w+',
#  '\\w+ion\\Wcontra\\w+',
#  '\\w+ion\\Wbene\\w+',
#  '\\w+ion\\Wtrans\\w+',
#  '\\w+ion\\W\\w+fle[cx]\\w+',
#  '\\w+ion\\W\\w+rupt\\w+',
#  '\\w+ion\\W\\w+graph\\w+',
#  '\\w+ion\\Wpost\\w+',
#  '\\w+ion\\W\\w+tial',
#  '\\w+ion\\Wmal\\w+',
#  '\\w+ion\\W\\w+ism',
#  '\\w+ion\\Wdia\\w+',
#  '\\w+ion\\W\\w+homo?\\w+',
#  '\\w+ion\\Wmulti\\w+',
#  '\\w+ion\\W\\w+gr(ad|ess)\\w+',
#  '\\w+ion\\Wanti\\w+',
#  '\\w+ion\\Wmono\\w+',
#  '\\w+ion\\W\\w+logy',
#  '\\w+ion\\W\\w+spire\\w+',
#  'in\\w+\\Wa\\w+',
#  'in\\w+\\Wan\\w+',
#  'in\\w+\\W\\w+er',
#  'in\\w+\\Wco\\w+',
#  'in\\w+\\W\\w+ly',
#  'in\\w+\\Wbe\\w+',
#  'in\\w+\\Wre\\w+',
#  'in\\w+\\W\\w+or',
#  'in\\w+\\W\\w+ion',
#  'in\\w+\\Win\\w+',
#  'in\\w+\\Wde\\w+',
#  'in\\w+\\Wdi\\w+',
#  'in\\w+\\W\\w+ent',
#  'in\\w+\\W\\w+geo?\\w+',
#  'in\\w+\\W\\w+al',
#  'in\\w+\\Wcom\\w+',
#  'in\\w+\\Wcon\\w+',
#  'in\\w+\\Wun\\w+',
#  'in\\w+\\Wex\\w+',
#  'in\\w+\\Wen\\w+',
#  'in\\w+\\Wpro\\w+',
#  'in\\w+\\W\\w+ation',
#  'in\\w+\\W\\w+ive',
#  'in\\w+\\Wdis\\w+',
#  'in\\w+\\W\\w+ous',
#  'in\\w+\\W\\w+ate',
#  'in\\w+\\W\\w+ure',
#  'in\\w+\\Wpre\\w+',
#  'in\\w+\\W\\w+ment',
#  'in\\w+\\W\\w+ence',
#  'in\\w+\\W\\w+able',
#  'in\\w+\\W\\w+ant',
#  'in\\w+\\W\\w+ity',
#  'in\\w+\\W\\w+ness',
#  'in\\w+\\W\\w+ance',
#  'in\\w+\\W\\w+ful',
#  'in\\w+\\Wim\\w+',
#  'in\\w+\\W\\w+age',
#  'in\\w+\\W\\w+ish',
#  'in\\w+\\W\\w+ic',
#  'in\\w+\\W\\w+ary',
#  'in\\w+\\W\\w+mi[ts]\\w+',
#  'in\\w+\\W\\w+bio?\\w+',
#  'in\\w+\\W\\w+ise',
#  'in\\w+\\Wbi\\w+',
#  'in\\w+\\W\\w+less',
#  'in\\w+\\Winter\\w+',
#  'in\\w+\\Wmis\\w+',
#  'in\\w+\\W\\w+ible',
#  'in\\w+\\Wcol\\w+',
#  'in\\w+\\Wtri\\w+',
#  'in\\w+\\W\\w+spect?\\w+',
#  'in\\w+\\Wem\\w+',
#  'in\\w+\\W\\w+pan\\w+',
#  'in\\w+\\W\\w+ver[ts]\\w+',
#  'in\\w+\\Wsub\\w+',
#  'in\\w+\\W\\w+press\\w+',
#  'in\\w+\\W\\w+port\\w+',
#  'in\\w+\\W\\w+ian',
#  'in\\w+\\W\\w+auto?\\w+',
#  'in\\w+\\W\\w+ist',
#  'in\\w+\\W\\w+dict?\\w+',
#  'in\\w+\\W\\w+form\\w+',
#  'in\\w+\\Wil\\w+',
#  'in\\w+\\Wnon\\w+',
#  'in\\w+\\W\\w+ship',
#  'in\\w+\\W\\w+scri(pt|b)\\w+',
#  'in\\w+\\W\\w+stru(ct)?\\w+',
#  'in\\w+\\W\\w+eer',
#  'in\\w+\\W\\w+c[ae]pt\\w+',
#  'in\\w+\\W\\w+cial',
#  'in\\w+\\W\\w+cide\\w+',
#  'in\\w+\\W\\w+fact?\\w+',
#  'in\\w+\\W\\w+p(el|uls)\\w+',
#  'in\\w+\\Wir\\w+',
#  'in\\w+\\W\\w+ject\\w+',
#  'in\\w+\\W\\w+tude',
#  'in\\w+\\Wuni\\w+',
#  'in\\w+\\W\\w+hood',
#  'in\\w+\\W\\w+tract\\w+',
#  'in\\w+\\W\\w+ize',
#  'in\\w+\\W\\w+pa(th|ss)\\w+',
#  'in\\w+\\Wcontra\\w+',
#  'in\\w+\\Wbene\\w+',
#  'in\\w+\\Wtrans\\w+',
#  'in\\w+\\W\\w+fle[cx]\\w+',
#  'in\\w+\\W\\w+rupt\\w+',
#  'in\\w+\\W\\w+graph\\w+',
#  'in\\w+\\Wpost\\w+',
#  'in\\w+\\W\\w+tial',
#  'in\\w+\\Wmal\\w+',
#  'in\\w+\\W\\w+ism',
#  'in\\w+\\Wdia\\w+',
#  'in\\w+\\W\\w+homo?\\w+',
#  'in\\w+\\Wmulti\\w+',
#  'in\\w+\\W\\w+gr(ad|ess)\\w+',
#  'in\\w+\\Wanti\\w+',
#  'in\\w+\\Wmono\\w+',
#  'in\\w+\\W\\w+logy',
#  'in\\w+\\W\\w+spire\\w+',
#  ...]

# %%
for i, regex in enumerate(cross):
  exp_path = os.path.join(PROJECT_DIR, f'exp/morphemes-ngrams/exp{i:04}')
  os.makedirs(exp_path, exist_ok=True)
  if(os.path.exists(os.path.join(exp_path, 'doc.txt'))):
    os.remove(os.path.join(exp_path, 'doc.txt'))
  os.symlink(ENGLISH, os.path.join(exp_path, 'doc.txt'))
  with open(os.path.join(exp_path, 'rematch.rgx'), 'w') as fp:
    fp.write(f'\W!x{{{regex}}}\W')
  with open(os.path.join(exp_path, 'perl.rgx'), 'w') as fp:
    fp.write(f'\W({regex})\W')
  with open(os.path.join(exp_path, 'boost.rgx'), 'w') as fp:
    fp.write(f'\W({regex})\W')
